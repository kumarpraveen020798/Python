# %% [markdown]
# # 1. Create a string "Python Programming" and print only "Programming" using slicing

# %%
string = "Pyhton Programming"
index_no = string.find("Programming")
print(string[index_no:])
# Out:
# Programming

# %% [markdown]
# # 2. From "Hello World", print "World" using negative indexing

# %%
string = "Hello World"
a = string.find("World")
negative_index = a - len(string)
print("Negative Index of World is " , negative_index)
print(string[negative_index :])
# Out:
# Negative Index of World is  -5
# World

# %% [markdown]
# # 3. Given text = "Developer", print every second character using slicing

# %%
text = "Developer"
print(text[::2])
# Out:
# Dvlpr

# %% [markdown]
# # 4. Reverse the string "OpenAI" using slicing

# %%
string = "OpenAI"
print(string[::-1])
# Out:
# IAnepO

# %% [markdown]
# # 5. Extract "gram" from "Programming" using slicing

# %%
string = "Programming"
start = string.find("gram")
end = start + len("gram")
print(string[start:end])
# Out:
# gram

# %% [markdown]
# # 6. Given text = "Data Science", replace "Science" with "Analysis"

# %%
text = "Data Science"
print(text.replace("Science" , "Analysis"))
# Out:
# Data Analysis

# %% [markdown]
# # 7. Convert "python is fun" into uppercase and store it in a new variable

# %%
string = "python is fun"
a = string.upper()
print(a)
# Out:
# PYTHON IS FUN

# %% [markdown]
# # 8. Convert "WELCOME" into lowercase and print it

# %%
string = "WELCOME"
print(string.lower())
# Out:
# welcome

# %% [markdown]
# # 9. Count how many times "e" appears in "experience"

# %%
string = "experience"
print(string.count("e"))
# Out:
# 4

# %% [markdown]
# # 10.Find the index of "a" in "banana" (first occurrence)

# %%
string = "banana"
print(string.index("a"))
# Out:
# 1

# %% [markdown]
# # 11. Remove leading and trailing spaces from " Hello Python "

# %%
string = " Hello Python "
print(string.strip())
# Out:
# Hello Python

# %% [markdown]
# # 12. Replace all spaces in "I love coding" with _

# %%
string = "I love coding"
print(string.replace(" ","_"))
# Out:
# I_love_coding

# %% [markdown]
# # 13. From "ABCDEFGHIJ", extract "CDEFG" using slicing

# %%
string = "ABCDEFGHIJ"
start = string.find("CDEFG")
end = start + len("CDEFG")
print(string[start:end])
# Out:
# CDEFG

# %% [markdown]
# # 14. Print the last 4 characters of "JavaScript"

# %%
string = "JavaScript"
print(string[-4:])
# Out:
# ript

# %% [markdown]
# # 15. From "FullStack", print characters from index 1 to second last

# %%
string = "FullStack"
print(string[1:-1])
# Out:
# ullStac

# %% [markdown]
# # 16. Create variables: name = "Aman", age = 25. Use f-string to print "My name is Aman and I am 25 years old"

# %%
name = "Aman"
age = 25
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Aman and I am 25 years old

# %% [markdown]
# # 17. Create variables: apples = 3, bananas = 2. Use .format() to print "I have 3 apples and 2 bananas"

# %%
apples = 3
bananas = 2 
print("I have {} apples and {} bananas".format(apples,bananas))
# Out:
# I have 3 apples and 2 bananas

# %% [markdown]
# # 18. Print the string: This is "Python" using escape characters

# %%
print("This is \"Python\"")
# Out:
# This is "Python"

# %% [markdown]
# # 19. Create a multi-line string for an address using triple quotes

# %%
address = """Near Sanjay Public School
Krishna Nagar , Meerut ,  Uttar Pradesh"""
print("Address is :" ,address)
# Out:
# Address is : Near Sanjay Public School
# Krishna Nagar , Meerut ,  Uttar Pradesh

# %% [markdown]
# # 20. Print a string with a new line using \n

# %%
print("Hello my name is Praveen Kumar \nand I am learning Python ")
# Out:
# Hello my name is Praveen Kumar
# and I am learning Python

# %% [markdown]
# # 21. Convert "hello world" into "Hello World" using string methods

# %%
string = "hello world"
print(string.title())
# Out:
# Hello World

# %% [markdown]
# # 22. Swap the case of "PyThOn"

# %%
string = "PyThOn"
print(string.swapcase())
# Out:
# pYtHoN

# %% [markdown]
# # 23. Find the length of "Artificial Intelligence"

# %%
string = "Artificial Intelligence"
print(len(string)) # using variable
print(len("Artificial Intelligence")) #directly
# Out:
# 23
# 23

# %% [markdown]
# # 24. From "MachineLearning", extract "Learning" using slicing

# %%
string = "MachineLearning"
start = string.find("Learning")
print(string[start:])
# Out:
# Learning

# %% [markdown]
# # 25. Print characters from index 2 to 8 in "DataAnalytics"

# %%
string = "DataAnalytics"
print(string[2:8])
# Out:
# taAnal

# %% [markdown]
# # 26. Replace "2024" with "2025" in "Happy New Year 2024"

# %%
string = "Happy New Year 2024"
print(string.replace("2024","2025"))
# Out:
# Happy New Year 2025

# %% [markdown]
# # 27. Find the position of "@" in "user@gmail.com"

# %%
string = "user@gmail.com"
print(string.find("@"))
# Out:
# 4

# %% [markdown]
# # 28. Convert "123" (string) into integer

# %%
string = "123"
num = int(string)
print(num)
# Out:
# 123

# %% [markdown]
# # 29. Convert integer 456 into string and concatenate with "Number: "

# %%
num = "456"
print("Number:"+str(num))
# Out:
# Number:456

# %% [markdown]
# # 30. Remove all occurrences of "a" from "banana" using string methods

# %%
string = "banana"
print(string.replace("a",""))
# Out:
# bnn
